# %% [markdown]
# # genai-17: Persistent Chat History with Firebase
#
# **Industry:** QSR (Quick Service Restaurants)
#
# A QSR chain's order-assistant chatbot should remember a regular customer's usual order across visits and devices. Build a chatbot that stores and retrieves conversation history from Firebase Firestore.

# %%
# Dependencies required:
# Firebase Firestore, firebase-admin SDK, LangChain, Python

# %%
# Use FirestoreChatMessageHistory from langchain-google-firestore

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why choose Firestore over local storage (e.g., SQLite) for chat history?**
# [Add answer here]
#
# **What data model would you use to store messages per user/session?**
# [Add answer here]
