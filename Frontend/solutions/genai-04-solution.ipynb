# %% [markdown]
# # genai-04: RAG Pipeline with ChromaDB
#
# **Industry:** Healthcare
#
# A hospital wants clinicians to quickly query internal treatment protocols instead of digging through PDFs. Build a Retrieval-Augmented Generation (RAG) system that answers clinical questions from a custom protocol/guideline document using a vector database.

# %%
# Dependencies required:
# LangChain, ChromaDB, HuggingFace/Gemini embeddings, Python

# %%
from langchain_community.vectorstores import Chroma
# Build the RAG chain here

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why is RAG better than fine-tuning for factual QA?**
# [Add answer here]
#
# **What is cosine similarity used for here?**
# [Add answer here]
