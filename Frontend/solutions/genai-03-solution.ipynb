# %% [markdown]
# # genai-03: Parallel & Conditional Chains
#
# **Industry:** Insurance
#
# An insurance company wants to speed up claims processing. Build a chain that analyzes a claim's damage description and supporting evidence simultaneously (parallel: damage assessment + fraud-risk check), and a second chain that routes the claim to 'auto-approve' or 'manual review' conditionally based on the risk score.

# %%
# Dependencies required:
# LangChain, RunnableParallel, RunnableBranch, any LLM API

# %%
from langchain_core.runnables import RunnableParallel, RunnableBranch
# Construct parallel and conditional chains

# %% [markdown]
# ### Knowledge Test Answers
#
# **When would you use parallel over conditional chains?**
# [Add answer here]
#
# **How does RunnableBranch decide which path to take?**
# [Add answer here]
