# %% [markdown]
# # genai-20: Nested Subgraph Multi-Agent Architecture
#
# **Industry:** Insurance
#
# An insurer wants an end-to-end claims-processing assistant: one outer flow that manages the whole claim lifecycle, and an inner flow that specifically handles damage assessment. Build a LangGraph system where a top-level supervisor graph calls a nested subgraph as a single node.

# %%
# Dependencies required:
# LangGraph, Python, any LLM API

# %%
from langgraph.graph import StateGraph
# Build child graph and add it as a node to the parent graph

# %% [markdown]
# ### Knowledge Test Answers
#
# **What's the benefit of a subgraph over just adding more nodes to one big graph?**
# [Add answer here]
#
# **How does state get passed between the outer graph and the subgraph?**
# [Add answer here]
