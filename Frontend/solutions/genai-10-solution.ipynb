# %% [markdown]
# # genai-10: Human-in-the-Loop Approval Workflow
#
# **Industry:** Financial Services
#
# A trading desk needs an AI assistant that can prep trades but must never execute one without a human sign-off. Build a LangGraph workflow that pauses execution and waits for human approval before proceeding with a sensitive action (e.g., executing a trade or sending a client email).

# %%
# Dependencies required:
# LangGraph, Python

# %%
# Define interrupt node with LangGraph's Command/Interrupt

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why is human-in-the-loop important for agentic systems?**
# [Add answer here]
#
# **What's the difference between interrupt and simply pausing with input()?**
# [Add answer here]
