# %% [markdown]
# # Vendor Invoice Extractor - Solution Notebook
# **Industry:** Accounts Payable
#
# This notebook contains a concrete implementation for the **Vendor Invoice Extractor**.
# It demonstrates how to process specific business inputs and generate an AI response using the Groq API.

# %% [markdown]
# ## Task Instructions
# Your task is to build an agent that automatically performs OCR data extraction. The user will input raw invoice text, and the agent must parse out the key fields (invoice number, total due, etc.) into a structured format.

# %%
# !pip install -q groq
import os
import json
from groq import Groq

# Initialize the Groq client (ensure your GROQ_API_KEY is set in your environment variables)
# os.environ["GROQ_API_KEY"] = "gsk_..." 
client = Groq()

# %% [markdown]
# ## 1. Define Business Inputs
# Here we define the mock data (e.g. resumes, policies, or client queries) that the agent will process.

# %%
invoice_ocr_text = "INVOICE #9981. Vendor: CloudServe Inc. Date: 2026-08-01. Total Due: $1,250.00. Tax: $100.00."

# %% [markdown]
# ## 2. Prompt Design & System Instructions
# Below is the core system prompt that dictates the agent's behavior and constraints.

# %%
system_prompt = """You are a Finance Operations AI. Extract the key fields from the invoice text into a structured JSON object with keys: invoice_number, vendor_name, date, total_due, and tax."""

user_prompt = f'''OCR Text: {invoice_ocr_text}'''

print("System Prompt:")
print(system_prompt)
print("\nUser Prompt:")
print(user_prompt)

# %% [markdown]
# ## 3. Agent Execution
# We will now call the Groq LLM API using the defined prompts to generate the response.

# %%
def run_agent(system_msg, user_msg):
    try:
        response = client.chat.completions.create(
            model="llama3-8b-8192",
            messages=[
                {"role": "system", "content": system_msg},
                {"role": "user", "content": user_msg}
            ],
            temperature=0.0
        )
        return response.choices[0].message.content
    except Exception as e:
        # Fallback mock response for testing without an API key
        return json.dumps({"status": "mock_response", "message": "API Key not provided. This is a fallback mock output."}, indent=2)

result = run_agent(system_prompt, user_prompt)
print("\n--- Agent Output ---")
print(result)
