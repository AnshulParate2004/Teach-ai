# %% [markdown]
# # genai-05: Metadata-Filtered RAG
#
# **Industry:** Law Firms
#
# A law firm's associates need to search case law without wading through irrelevant jurisdictions. Extend a basic RAG system to filter retrieval results using metadata (e.g., only search precedents from a specific jurisdiction/year/court).

# %%
# Dependencies required:
# LangChain, ChromaDB/Qdrant, Python

# %%
# Pass metadata filters to your retriever
retriever = vectorstore.as_retriever(search_kwargs={"filter": {"year": 2023}})

# %% [markdown]
# ### Knowledge Test Answers
#
# **What's the benefit of metadata filtering over pure semantic search?**
# [Add answer here]
#
# **Give an example use case where this is essential.**
# [Add answer here]
