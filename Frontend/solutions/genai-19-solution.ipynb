# %% [markdown]
# # genai-19: Web Scraping Agent with Search API Integration
#
# **Industry:** Retail & E-Commerce
#
# A retail brand's pricing team wants to track competitor pricing and promotions automatically. Build an agent that takes a research query, searches the web using the Serper API, scrapes the top results, and summarizes findings from multiple sources.

# %%
# Dependencies required:
# Serper API, requests/BeautifulSoup, LangChain, Python

# %%
# Setup Tavily or Serper + BeautifulSoup for the web scraping agent

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why use a search API instead of scraping search engine pages directly?**
# [Add answer here]
#
# **What are the risks/limitations of scraping arbitrary websites?**
# [Add answer here]
