# %% [markdown]
# # genai-12: Building a Custom MCP Server (File Manager)
#
# **Industry:** Telecommunications
#
# A telecom NOC team wants an LLM assistant that can safely read and edit network configuration files. Build a Model Context Protocol (MCP) server that exposes file operations (read, write, edit, search) as tools an LLM client can call.

# %%
# Dependencies required:
# Python mcp SDK, FastAPI, UV package manager

# %%
from mcp.server.fastmcp import FastMCP
# Create FastMCP server and tools

# %% [markdown]
# ### Knowledge Test Answers
#
# **What problem does MCP solve compared to hardcoding tool integrations?**
# [Add answer here]
#
# **What is the role of stdio transport in MCP servers?**
# [Add answer here]
