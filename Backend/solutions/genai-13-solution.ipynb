# %% [markdown]
# # genai-13: Full-Stack MCP Application with FastAPI + Gemini
#
# **Industry:** Automotive
#
# An automotive dealer network wants a single API that lets service advisors query vehicle diagnostics via chat. Build a full-stack application where a FastAPI backend connects an MCP client to an MCP server and exposes a /query endpoint powered by Gemini.

# %%
# Dependencies required:
# FastAPI, MCP SDK, Gemini API, Python, CORS middleware

# %%
# Setup FastAPI app with MCP client connection lifecycle

# %% [markdown]
# ### Knowledge Test Answers
#
# **What is the flow of a request from frontend -> FastAPI -> MCP client -> MCP server -> LLM?**
# [Add answer here]
#
# **Why is async lifecycle management important here?**
# [Add answer here]
