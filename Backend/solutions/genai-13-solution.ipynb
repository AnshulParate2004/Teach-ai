# %% [markdown]
# # genai-13: Full-Stack MCP Application with FastAPI + Gemini
#
# **Company:** DriveTech Motors | **Role:** Full-Stack GenAI Intern
# **Industry:** Automotive Services
#
# ### Problem Statement
# DriveTech Motors dealership network needs an API letting service advisors query vehicle diagnostic telemetry. Build a full-stack REST API in FastAPI connecting an MCP client to a vehicle diagnostic tool server, exposing a /query endpoint powered by Gemini.
#
# ### Task
# A working API where a POST request to /query (e.g. 'why is check engine light on for VIN X') triggers Gemini to reason, invoke MCP diagnostic tools, and return structured responses.

# %%
# Dependencies required:
# FastAPI, MCP SDK, Gemini API, Python, CORS Middleware

# %%
from fastapi import FastAPI
from mcp import ClientSession

app = FastAPI()
@app.post('/query')
async def handle_query(prompt: str):
    pass

# %% [markdown]
# ### Knowledge Test Answers
#
# **Trace request lifecycle flow: Frontend -> FastAPI -> MCP Client -> MCP Server -> LLM.**
# [Add answer here]
#
# **Why is async context management essential when handling MCP client connections in FastAPI?**
# [Add answer here]
