# %% [markdown]
# # Task_2_Data_Setup
# ## Faq Dataset Prep

# %%
import json

faqs = [
    {'question': 'How do I reset my password?', 'answer': 'Click Forgot Password on the login page and follow the email instructions.'},
    {'question': 'How do I get a refund?', 'answer': 'Refunds are processed within 30 days. Submit a request via Account -> Billing -> Request Refund.'},
    {'question': 'How do I add a team member?', 'answer': 'Go to Settings -> Team -> Invite Member. Enter their email and select their role.'},
    {'question': 'Why is my invoice higher than usual?', 'answer': 'Check for additional seats or usage overages in Account -> Billing -> Usage History.'},
    {'question': 'How do I integrate with Slack?', 'answer': 'Go to Integrations -> Slack -> Connect. Authorize the app and select your workspace channel.'},
]

with open('faqs.json', 'w') as f:
    json.dump(faqs, f, indent=2)
print(f'FAQ dataset created: {len(faqs)} entries')
