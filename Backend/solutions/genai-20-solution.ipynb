# %% [markdown]
# # genai-20: Nested Subgraph Multi-Agent Architecture
#
# **Company:** OmniInsurance Group | **Role:** Enterprise Agent Architect Intern
# **Industry:** Enterprise Insurance
#
# ### Problem Statement
# OmniInsurance Group wants an enterprise claims workflow: an outer supervisor graph managing overall claim lifecycle, calling a compiled inner damage-assessment subgraph (its own multi-step research workflow) as a single execution node.
#
# ### Task
# A functional two-level state graph: outer claims supervisor routes to damage-assessment subgraph node, which internally runs multi-step nodes (photos -> estimate -> summary) before returning to outer graph.

# %%
# Dependencies required:
# LangGraph, Python, Gemini/Groq API

# %%
from langgraph.graph import StateGraph
# Build inner damage assessment subgraph, compile, and add to outer supervisor graph

# %% [markdown]
# ### Knowledge Test Answers
#
# **What architectural advantages does nesting subgraphs offer over adding more nodes to one main graph?**
# [Add answer here]
#
# **How is state passed and isolated between parent supervisor graphs and child subgraphs?**
# [Add answer here]
