# %% [markdown]
# # genai-19: Web Scraping Agent with Search API Integration
#
# **Company:** PriceWatch Retail | **Role:** Market Intelligence AI Intern
# **Industry:** Retail Intelligence
#
# ### Problem Statement
# PriceWatch Retail pricing analysts track competitor prices and promotions automatically. Build an agent that accepts research queries, searches the web via Serper API, scrapes top result URL pages, and synthesizes findings into structured reports.
#
# ### Task
# Given a query ('latest discount trends from competing electronics retailers'), the agent returns a synthesized summary report combining scraped text from at least 3 sources with citations.

# %%
# Dependencies required:
# Serper API, requests/BeautifulSoup, LangChain, Python

# %%
import requests
from bs4 import BeautifulSoup
# Search via Serper API, scrape target URLs, and summarize results with LLM

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why use a Search API instead of directly scraping search engine results pages?**
# [Add answer here]
#
# **What technical limitations and risks occur when scraping arbitrary target web pages?**
# [Add answer here]
