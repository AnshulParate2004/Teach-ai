# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [2]</a>'.</span>

# %% [markdown]
# # 12. Building a Custom MCP Server (File Manager)
# **Industry:** Telecommunications
#
# Build a Model Context Protocol (MCP) server that exposes file operations (read, write) as tools an LLM client can call.

# %%
# !pip install mcp
# Out:
# Collecting mcp
#   Downloading mcp-2.0.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: anyio>=4.9 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from mcp) (4.14.2)
# Collecting httpx2>=2.5.0 (from mcp)
#   Downloading httpx2-2.9.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from mcp) (4.26.0)
# Collecting mcp-types==2.0.0 (from mcp)
#   Downloading mcp_types-2.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from mcp) (1.44.0)
# Requirement already satisfied: pydantic>=2.12.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from mcp) (2.13.4)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp) (2.13.0)
# Collecting python-multipart>=0.0.9 (from mcp)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Collecting pywin32>=311 (from mcp)
#   Downloading pywin32-312-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting sse-starlette>=3.0.0 (from mcp)
#   Downloading sse_starlette-3.4.6-py3-none-any.whl.metadata (15 kB)
# Collecting starlette>=0.27 (from mcp)
#   Using cached starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=4.13.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from mcp) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from mcp) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from mcp) (0.52.1)
# Requirement already satisfied: idna>=2.8 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from anyio>=4.9->mcp) (3.18)
# Collecting httpcore2==2.9.1 (from httpx2>=2.5.0->mcp)
#   Downloading httpcore2-2.9.1-py3-none-any.whl.metadata (24 kB)
# Collecting truststore>=0.10 (from httpx2>=2.5.0->mcp)
#   Downloading truststore-0.10.4-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from httpcore2==2.9.1->httpx2>=2.5.0->mcp) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp) (2026.6.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.12.0->mcp) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.12.0->mcp) (2.46.4)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp) (50.0.0)
# Requirement already satisfied: click>=7.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.31.1->mcp) (8.4.2)
# Requirement already satisfied: colorama in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from click>=7.0->uvicorn>=0.31.1->mcp) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.1.1)
# Requirement already satisfied: pycparser in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (3.0)
# Downloading mcp-2.0.0-py3-none-any.whl (349 kB)
# Downloading mcp_types-2.0.0-py3-none-any.whl (69 kB)
# Downloading httpx2-2.9.1-py3-none-any.whl (91 kB)
# Downloading httpcore2-2.9.1-py3-none-any.whl (82 kB)
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading pywin32-312-cp313-cp313-win_amd64.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.9 MB 5.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/6.9 MB 2.8 MB/s eta 0:00:02
#    ------------ --------------------------- 2.1/6.9 MB 2.8 MB/s eta 0:00:02
#    --------------- ------------------------ 2.6/6.9 MB 2.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/6.9 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 3.7/6.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/6.9 MB 2.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/6.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/6.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 2.8 MB/s eta 0:00:00
# Downloading sse_starlette-3.4.6-py3-none-any.whl (16 kB)
# Using cached starlette-1.3.1-py3-none-any.whl (73 kB)
# Downloading truststore-0.10.4-py3-none-any.whl (18 kB)
# Installing collected packages: truststore, pywin32, python-multipart, starlette, httpcore2, sse-starlette, mcp-types, httpx2, mcp
# Successfully installed httpcore2-2.9.1 httpx2-2.9.1 mcp-2.0.0 mcp-types-2.0.0 python-multipart-0.0.32 pywin32-312 sse-starlette-3.4.6 starlette-1.3.1 truststore-0.10.4
# [notice] A new release of pip is available: 24.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
from mcp.server.fastmcp import FastMCP

# Create an MCP server
mcp = FastMCP("File Manager")

@mcp.tool()
def read_file(path: str) -> str:
    """Reads a network config file"""
    try:
        with open(path, 'r') as f:
            return f.read()
    except Exception as e:
        return str(e)

@mcp.tool()
def write_file(path: str, content: str) -> str:
    """Writes to a network config file"""
    try:
        with open(path, 'w') as f:
            f.write(content)
        return "Success"
    except Exception as e:
        return str(e)

print("Run this script directly via stdio transport: `uv run mcp_server.py`")
# mcp.run(transport='stdio')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from mcp.server.fastmcp import FastMCP
#       2
#       3 # Create an MCP server
#       4 mcp = FastMCP("File Manager")
#
# ModuleNotFoundError: No module named 'mcp'
