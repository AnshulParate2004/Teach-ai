# %% [markdown]
# # genai-04: RAG Pipeline with ChromaDB
#
# **Company:** MedCare Health Systems | **Role:** Clinical RAG Systems Engineer Intern
# **Industry:** Healthcare
#
# ### Problem Statement
# MedCare Health Systems needs an AI tool for clinicians to query internal medical treatment guidelines quickly. Build a Retrieval-Augmented Generation (RAG) system that answers clinical questions grounded strictly in custom protocol documents stored in a ChromaDB vector database with explicit source citations.
#
# ### Task
# Input: a clinical guideline PDF document + a doctor's medical query. Output: an accurate, context-grounded answer displaying exact guideline passage citations for clinical auditability.

# %%
# Dependencies required:
# LangChain, ChromaDB, HuggingFace/Gemini embeddings, Python

# %%
from langchain_community.vectorstores import Chroma
from langchain_core.prompts import ChatPromptTemplate

# Build ChromaDB retriever and context-grounded RAG chain

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why is RAG preferred over fine-tuning for factual QA over dynamic medical guidelines?**
# [Add answer here]
#
# **What is cosine similarity and how is it used in vector retrieval?**
# [Add answer here]
