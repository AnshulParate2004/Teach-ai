# %% [markdown]
# # 2. Structured Output with Pydantic
# **Industry:** Retail & E-Commerce
#
# Analyze a raw product description and return structured catalog data.

# %%
# !pip install langchain langchain-openai pydantic python-dotenv
# Out:
# Requirement already satisfied: langchain in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (1.3.14)
# Requirement already satisfied: langchain-openai in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (1.4.1)
# Requirement already satisfied: pydantic in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (2.13.4)
# Requirement already satisfied: python-dotenv in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.5.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.2.10)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (2.53.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: sniffio in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: regex in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: requests in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.34.2)
# Requirement already satisfied: idna>=2.8 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.45.0->langchain-openai) (3.18)
# Requirement already satisfied: certifi in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.45.0->langchain-openai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.45.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.7.0)
# Requirement already satisfied: colorama in c:\users\kaizen\appdata\local\programs\python\python313\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# [notice] A new release of pip is available: 24.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pydantic import BaseModel, Field
import os
from langchain_openai import AzureChatOpenAI
import os

# os.environ['GOOGLE_API_KEY'] = 'your-api-key-here'
llm = AzureChatOpenAI(azure_deployment=os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME", "gpt-4o"), api_version=os.environ.get("AZURE_OPENAI_API_VERSION", "2024-02-15-preview"))

class ProductSchema(BaseModel):
    title: str = Field(description="The name of the product")
    category: str = Field(description="The category of the product (e.g. Electronics, Clothing)")
    price_tier: str = Field(description="'Budget', 'Mid-range', or 'Premium'")
    summary: str = Field(description="A short 1-sentence summary of the product")

structured_llm = llm.with_structured_output(ProductSchema)

description = "The new QuantumBook Pro 15 features an ultra-fast M4 chip, a stunning 4K OLED display, and costs $2499. Perfect for professional video editors."

result = structured_llm.invoke(description)
print(result.model_dump_json(indent=2))
# Out:
# {
#   "title": "QuantumBook Pro 15",
#   "category": "Computers",
#   "price_tier": "Premium",
#   "summary": "A powerful laptop with advanced features tailored for professional video editing."
# }
