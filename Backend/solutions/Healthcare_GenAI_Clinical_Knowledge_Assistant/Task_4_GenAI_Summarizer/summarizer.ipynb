# %% [markdown]
# # Task_4_GenAI_Summarizer
# ## Summarizer

# %%
from openai import OpenAI
client = OpenAI()

def summarize_for_patient(abstract: str) -> str:
    return 'Simulated: This research found the new treatment is more effective with fewer side effects. Discuss with your doctor.'

abstract = 'Semaglutide reduced HbA1c by 1.8% vs 0.9% for metformin over 26 weeks in 500 T2D patients.'
print('Abstract:', abstract)
print('Patient Summary:', summarize_for_patient(abstract))
