# %% [markdown]
# # Task_2_Data_Setup
# ## Vector Store Setup

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain.schema import Document

embeddings = OpenAIEmbeddings()

clinical_docs = [
    Document(page_content='Metformin is first-line for Type 2 Diabetes.', metadata={'source': 'ADA 2024'}),
    Document(page_content='Hypertension: BP > 130/80 mmHg consistently.', metadata={'source': 'AHA 2023'}),
    Document(page_content='Amoxicillin 500mg TID x 7 days for community pneumonia.', metadata={'source': 'IDSA 2022'}),
]

# vectorstore = Chroma.from_documents(clinical_docs, embeddings, persist_directory='./clinical_db')
print(f'Simulated: {len(clinical_docs)} clinical documents indexed into ChromaDB.')
