# %% [markdown]
# # genai-06: Chatbot with Persistent Memory (LangGraph)
#
# **Company:** Vertex National Bank | **Role:** Conversational AI Systems Intern
# **Industry:** Banking & FinTech
#
# ### Problem Statement
# Vertex National Bank's customer support bot keeps forgetting customer loan application details between chat turns. Build a chatbot using LangGraph StateGraph that remembers context across turns and persistent user sessions using SQLite checkpointing.
#
# ### Task
# A banking support chatbot that recalls earlier messages (loan ID, income details) in the same session, and resumes state cleanly after application restart without asking repetitive questions.

# %%
# Dependencies required:
# LangGraph, SQLite, Python, Gemini/Groq API

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.sqlite import SqliteSaver

# Define StateGraph with SQLite checkpoint saver

# %% [markdown]
# ### Knowledge Test Answers
#
# **What is a checkpoint in LangGraph and how does it differ from in-memory message history lists?**
# [Add answer here]
#
# **How do thread IDs isolate separate user support sessions in SQLite checkpointers?**
# [Add answer here]
