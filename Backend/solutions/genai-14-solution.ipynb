# %% [markdown]
# # genai-14: Memory-Aware Chatbot with Mem0 + Vector DB
#
# **Industry:** Tourism
#
# A travel booking platform wants its chat concierge to remember a traveler's preferences across trips. Build a chatbot with hybrid memory (short-term conversation + long-term vector-searchable memory) using Mem0 and a vector database.

# %%
# Dependencies required:
# Mem0, Qdrant/ChromaDB, Groq/Gemini, HuggingFace embeddings

# %%
# Initialize Mem0 memory client with a vector DB backend

# %% [markdown]
# ### Knowledge Test Answers
#
# **What's the difference between short-term and long-term memory in an agent?**
# [Add answer here]
#
# **Why use a vector DB instead of a simple key-value store for memory?**
# [Add answer here]
