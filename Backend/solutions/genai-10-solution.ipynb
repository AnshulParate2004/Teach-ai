# %% [markdown]
# # genai-10: Human-in-the-Loop Approval Workflow
#
# **Company:** QuantCapital Trading | **Role:** AI Risk & Governance Intern
# **Industry:** Financial Services
#
# ### Problem Statement
# QuantCapital trading desks mandate that automated AI assistants prep stock trades but never execute orders without human sign-off. Build a LangGraph workflow that pauses graph execution and waits for human approval before taking sensitive financial actions.
#
# ### Task
# A state graph that stops at a trade execution node, requests human sign-off (approve/reject), and proceeds with trade execution or halts order execution accordingly.

# %%
# Dependencies required:
# LangGraph, interrupt mechanism, Python

# %%
from langgraph.types import interrupt

# Define node with interrupt checkpoint for human approval

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why is human-in-the-loop architecture critical for autonomous financial agentic systems?**
# [Add answer here]
#
# **What is the difference between graph interrupt() and blocking Python input() calls?**
# [Add answer here]
