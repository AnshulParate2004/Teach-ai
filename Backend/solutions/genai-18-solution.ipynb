# %% [markdown]
# # genai-18: TypeScript MCP Server (Weather Data)
#
# **Company:** SkyWay Travel | **Role:** TypeScript & Node.js AI Developer Intern
# **Industry:** Tourism Tech
#
# ### Problem Statement
# SkyWay Travel trip-planning assistants need live weather data to alert travelers about destination conditions. Build a Model Context Protocol server in TypeScript/Node.js exposing a get_weather_by_city tool using stdio transport and Zod schema validation.
#
# ### Task
# A working TypeScript MCP server returning live weather data for destination cities when invoked by an MCP client, integrating directly into trip-planning workflows.

# %%
# Dependencies required:
# Node.js, @modelcontextprotocol/sdk, Zod, TypeScript, Weather REST API

# %%
import { Server } from '@modelcontextprotocol/sdk/server/index.js';
import { z } from 'zod';
// Define TypeScript MCP tool server with Zod schema validation

# %% [markdown]
# ### Knowledge Test Answers
#
# **Why is runtime schema validation (Zod) essential for tool parameters in MCP servers?**
# [Add answer here]
#
# **How does stdio transport differ from HTTP-based SSE transport in MCP implementations?**
# [Add answer here]
