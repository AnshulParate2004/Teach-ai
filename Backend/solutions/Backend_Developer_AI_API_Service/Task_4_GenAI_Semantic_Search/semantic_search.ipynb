# %% [markdown]
# # Task_4_GenAI_Semantic_Search
# ## Semantic Search

# %%
from openai import OpenAI
import numpy as np
from typing import List

client = OpenAI()

def get_embedding(text: str) -> List[float]:
    # r = client.embeddings.create(model='text-embedding-3-small', input=text)
    # return r.data[0].embedding
    np.random.seed(hash(text) % 1000)
    return np.random.rand(1536).tolist()

def cosine_similarity(a: List[float], b: List[float]) -> float:
    a, b = np.array(a), np.array(b)
    return float(np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b)))

docs = ['Refund policy: 30-day money back guarantee.',
        'Technical support is available 24/7.',
        'Premium plan includes 5 user seats.']

def semantic_search(query: str, top_k: int = 2):
    q_emb = get_embedding(query)
    scores = [(doc, cosine_similarity(q_emb, get_embedding(doc))) for doc in docs]
    return sorted(scores, key=lambda x: x[1], reverse=True)[:top_k]

if __name__ == '__main__':
    results = semantic_search('How do I get a refund?')
    for doc, score in results:
        print(f'[{score:.3f}] {doc}')
