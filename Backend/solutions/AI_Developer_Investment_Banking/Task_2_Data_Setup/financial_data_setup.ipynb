# %% [markdown]
# # Task_2_Data_Setup
# ## Financial Data Setup

# %%
import pandas as pd

technova = pd.DataFrame({
    'Year': [2021, 2022, 2023],
    'Revenue_M': [18, 28, 42],
    'EBITDA_M': [2.1, 4.2, 8.4],
    'ARR_M': [13, 19, 31],
    'Headcount': [85, 140, 220],
})

comps = pd.DataFrame({
    'Company': ['Palantir', 'C3.ai', 'DataRobot', 'Veritone'],
    'EV_Revenue_Multiple': [12.3, 8.1, 9.5, 6.2],
    'EV_EBITDA_Multiple': [45.2, 38.7, 41.3, 29.8],
})

print('TechNova Financials:'); print(technova.to_string(index=False))
print('\nComparable Companies:'); print(comps.to_string(index=False))
