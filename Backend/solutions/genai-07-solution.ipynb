# %% [markdown]
# # genai-07: ReAct Agent from Scratch
#
# **Company:** OmniRoute Logistics | **Role:** Agentic Workflow Engineer Intern
# **Industry:** Supply Chain & Logistics
#
# ### Problem Statement
# OmniRoute Logistics wants an agent that answers live shipment tracking inquiries. Implement a ReAct (Reason + Act) agent from scratch using LangGraph that reasons step-by-step and invokes external tools (e.g., shipment tracking API) to resolve questions.
#
# ### Task
# Given a query like 'Where is shipment #4521 right now and will it arrive on time?', the agent reasons, invokes the mock tracking tool, observes the API payload, and formulates the final answer.

# %%
# Dependencies required:
# LangGraph, Python, requests/mock REST API

# %%
# Define ReAct state and tool execution graph in LangGraph

# %% [markdown]
# ### Knowledge Test Answers
#
# **What are the 3 phases of the ReAct execution loop?**
# [Add answer here]
#
# **Why is the observation step critical before the agent proceeds to the next reasoning turn?**
# [Add answer here]
