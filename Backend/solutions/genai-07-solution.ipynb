# %% [markdown]
# # genai-07: ReAct Agent from Scratch
#
# **Industry:** Supply Chain
#
# A logistics company wants an assistant that can answer live shipment questions. Implement a ReAct (Reason + Act) agent using LangGraph that answers questions by reasoning step-by-step and calling an external tool (e.g., a shipment-tracking API).

# %%
# Dependencies required:
# LangGraph, Python, a public REST API, requests

# %%
# Define the Reason and Act nodes in LangGraph

# %% [markdown]
# ### Knowledge Test Answers
#
# **What are the 3 phases of the ReAct loop?**
# [Add answer here]
#
# **Why is observation important before the next reasoning step?**
# [Add answer here]
